# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size = 1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size = 1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base information
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}&q="
city_responses= [ ]

# Create Empty Lists
x = 1
count = 1
city_df = []
lat = [] 
long = []
Max_Temp = []
Humidity = []
Cloudiness = []
Wind_Speed = []
Country = []
Date = []

# Begining Print 
print("Beginning Data Retrieval")
print("------------------------")

# for loop to make a api request for the individual cities 
for city in cities:
    if x >= 51: 
        count+= 1
        x = 1
    try:
        city_data=requests.get(url + city).json()
        city_df.append(city_data['name'])
        lat.append(city_data['coord']['lat'])
        long.append(city_data['coord']['lon'])
        Max_Temp.append(city_data['main']['temp_max'])
        Humidity.append(city_data['main']["humidity"])
        Cloudiness.append(city_data["clouds"]['all'])
        Wind_Speed.append(city_data["wind"]['speed'])
        Country.append(city_data['sys']['country'])
        Date.append(city_data['dt'])
        city_responses.append(city_data)
        print(f"Processing Record {x} of set {count}|{city}")
        x+=1
    except: 
        print("City not found. Skipping... ")
        
# Final Print
print("------------------------")
print("Data Retrieval Complete ")
print("------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of set 1|san patricio
# Processing Record 2 of set 1|bluff
# Processing Record 3 of set 1|vestmannaeyjar
# Processing Record 4 of set 1|laguna
# Processing Record 5 of set 1|ostrovnoy
# City not found. Skipping...
# Processing Record 6 of set 1|busselton
# Processing Record 7 of set 1|nanortalik
# Processing Record 8 of set 1|puerto madero
# Processing Record 9 of set 1|torbay
# Processing Record 10 of set 1|nyurba
# Processing Record 11 of set 1|port alfred
# Processing Record 12 of set 1|lakhipur
# Processing Record 13 of set 1|carnarvon
# Processing Record 14 of set 1|bengkulu
# Processing Record 15 of set 1|vicuna
# Processing Record 16 of set 1|katsuura
# Processing Record 17 of set 1|kavaratti
# Processing Record 18 of set 1|ushuaia
# Processing Record 19 of set 1|dikson
# Processing Record 20 of set 1|pisco
# Processing Record 21 of set 1|fortuna
# Processing Record 22 of set 1|beian
# Processing Record 23 of set 1|borovoy
# Processing Record 24 of set 1|norman wells
# Processing Record 25 of set 1|vaini
# Processing Record 26 of set 1|anadyr
# City not found. Skipping...
# Processing Record 27 of set 1|beringovskiy
# Processing Record 28 of set 1|tuburan
# Processing Record 29 of set 1|klaksvik
# Processing Record 30 of set 1|kavieng
# City not found. Skipping...
# Processing Record 31 of set 1|albany
# Processing Record 32 of set 1|mahebourg
# Processing Record 33 of set 1|mar del plata
# Processing Record 34 of set 1|olafsvik
# Processing Record 35 of set 1|bandarbeyla
# Processing Record 36 of set 1|bredasdorp
# Processing Record 37 of set 1|guerrero negro
# Processing Record 38 of set 1|qaanaaq
# Processing Record 39 of set 1|gizo
# Processing Record 40 of set 1|saint-philippe
# Processing Record 41 of set 1|yulara
# Processing Record 42 of set 1|terra santa
# Processing Record 43 of set 1|punta arenas
# Processing Record 44 of set 1|challans
# Processing Record 45 of set 1|thompson
# Processing Record 46 of set 1|tadine
# Processing Record 47 of set 1|dingle
# Processing Record 48 of set 1|mataura
# Processing Record 49 of set 1|quatre cocos
# Processing Record 50 of set 1|hermanus
# Processing Record 1 of set 2|kapaa
# Processing Record 2 of set 2|vangaindrano
# Processing Record 3 of set 2|arraial do cabo
# Processing Record 4 of set 2|longyearbyen
# Processing Record 5 of set 2|mina
# Processing Record 6 of set 2|leningradskiy
# Processing Record 7 of set 2|cururupu
# Processing Record 8 of set 2|juneau
# Processing Record 9 of set 2|vila
# Processing Record 10 of set 2|petropavlovsk-kamchatskiy
# Processing Record 11 of set 2|rikitea
# Processing Record 12 of set 2|pergamino
# Processing Record 13 of set 2|new norfolk
# Processing Record 14 of set 2|auki
# Processing Record 15 of set 2|tasiilaq
# Processing Record 16 of set 2|hilo
# Processing Record 17 of set 2|wangqing
# Processing Record 18 of set 2|manono
# Processing Record 19 of set 2|landshut
# Processing Record 20 of set 2|itoman
# Processing Record 21 of set 2|hithadhoo
# Processing Record 22 of set 2|kelme
# Processing Record 23 of set 2|mackay
# Processing Record 24 of set 2|bronnoysund
# Processing Record 25 of set 2|esqueda
# Processing Record 26 of set 2|lebu
# City not found. Skipping...
# Processing Record 27 of set 2|sahuaripa
# Processing Record 28 of set 2|pangnirtung
# Processing Record 29 of set 2|east london
# Processing Record 30 of set 2|aktash
# Processing Record 31 of set 2|chuy
# Processing Record 32 of set 2|nikolskoye
# Processing Record 33 of set 2|leshukonskoye
# Processing Record 34 of set 2|maceio
# Processing Record 35 of set 2|nishihara
# Processing Record 36 of set 2|walvis bay
# Processing Record 37 of set 2|bathsheba
# Processing Record 38 of set 2|jamestown
# Processing Record 39 of set 2|marsa matruh
# Processing Record 40 of set 2|geraldton
# City not found. Skipping...
# Processing Record 41 of set 2|samarai
# Processing Record 42 of set 2|cherskiy
# Processing Record 43 of set 2|tenenkou
# Processing Record 44 of set 2|cape town
# Processing Record 45 of set 2|vostok
# City not found. Skipping...
# Processing Record 46 of set 2|diamantino
# Processing Record 47 of set 2|clyde river
# Processing Record 48 of set 2|coquimbo
# Processing Record 49 of set 2|harij
# Processing Record 50 of set 2|georgetown
# Processing Record 1 of set 3|senaki
# Processing Record 2 of set 3|atuona
# Processing Record 3 of set 3|sitka
# Processing Record 4 of set 3|tuatapere
# Processing Record 5 of set 3|bilibino
# Processing Record 6 of set 3|nizhniy tsasuchey
# Processing Record 7 of set 3|kirakira
# City not found. Skipping...
# Processing Record 8 of set 3|amahai
# Processing Record 9 of set 3|bambous virieux
# City not found. Skipping...
# Processing Record 10 of set 3|beloit
# Processing Record 11 of set 3|ancud
# Processing Record 12 of set 3|butaritari
# Processing Record 13 of set 3|gamba
# Processing Record 14 of set 3|terre haute
# Processing Record 15 of set 3|tyrma
# Processing Record 16 of set 3|inhambane
# Processing Record 17 of set 3|codrington
# Processing Record 18 of set 3|santa catalina
# Processing Record 19 of set 3|kudahuvadhoo
# Processing Record 20 of set 3|fort nelson
# Processing Record 21 of set 3|vila franca do campo
# Processing Record 22 of set 3|grand gaube
# Processing Record 23 of set 3|helong
# Processing Record 24 of set 3|severo-kurilsk
# Processing Record 25 of set 3|lompoc
# Processing Record 26 of set 3|inverell
# Processing Record 27 of set 3|aldan
# Processing Record 28 of set 3|kodiak
# Processing Record 29 of set 3|okato
# Processing Record 30 of set 3|abu samrah
# Processing Record 31 of set 3|phalaborwa
# Processing Record 32 of set 3|macapa
# Processing Record 33 of set 3|ponta do sol
# Processing Record 34 of set 3|cheyenne
# Processing Record 35 of set 3|salalah
# Processing Record 36 of set 3|sulangan
# Processing Record 37 of set 3|hambantota
# Processing Record 38 of set 3|faya
# Processing Record 39 of set 3|pacific grove
# Processing Record 40 of set 3|kattivakkam
# Processing Record 41 of set 3|cozumel
# Processing Record 42 of set 3|esperance
# City not found. Skipping...
# Processing Record 43 of set 3|saskylakh
# Processing Record 44 of set 3|ribeira grande
# Processing Record 45 of set 3|asau
# Processing Record 46 of set 3|puerto ayacucho
# Processing Record 47 of set 3|provideniya
# Processing Record 48 of set 3|porto novo
# Processing Record 49 of set 3|iqaluit
# Processing Record 50 of set 3|guane
# Processing Record 1 of set 4|saint-ambroise
# Processing Record 2 of set 4|acapulco
# Processing Record 3 of set 4|quthing
# Processing Record 4 of set 4|mudgee
# City not found. Skipping...
# Processing Record 5 of set 4|inuvik
# Processing Record 6 of set 4|avarua
# Processing Record 7 of set 4|hobyo
# Processing Record 8 of set 4|gaoyou
# Processing Record 9 of set 4|urucara
# Processing Record 10 of set 4|tshikapa
# Processing Record 11 of set 4|bairiki
# Processing Record 12 of set 4|lungi
# City not found. Skipping...
# Processing Record 13 of set 4|lavrentiya
# Processing Record 14 of set 4|kruisfontein
# Processing Record 15 of set 4|richmond
# Processing Record 16 of set 4|cherlak
# City not found. Skipping...
# Processing Record 17 of set 4|yanam
# City not found. Skipping...
# Processing Record 18 of set 4|okha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of set 4|byron bay
# Processing Record 20 of set 4|mountain home
# Processing Record 21 of set 4|creel
# City not found. Skipping...
# Processing Record 22 of set 4|necochea
# Processing Record 23 of set 4|pevek
# Processing Record 24 of set 4|puerto ayora
# Processing Record 25 of set 4|san quintin
# Processing Record 26 of set 4|cidreira
# Processing Record 27 of set 4|rambha
# Processing Record 28 of set 4|kostino
# City not found. Skipping...
# Processing Record 29 of set 4|humberto de campos
# Processing Record 30 of set 4|lugoba
# Processing Record 31 of set 4|luderitz
# Processing Record 32 of set 4|yellowknife
# Processing Record 33 of set 4|tuktoyaktuk
# City not found. Skipping...
# Processing Record 34 of set 4|kabalo
# City not found. Skipping...
# Processing Record 35 of set 4|hobart
# Processing Record 36 of set 4|timmins
# Processing Record 37 of set 4|san vicente
# Processing Record 38 of set 4|gaspe
# Processing Record 39 of set 4|lamu
# Processing Record 40 of set 4|ulladulla
# City not found. Skipping...
# Processing Record 41 of set 4|asilah
# Processing Record 42 of set 4|kaitangata
# Processing Record 43 of set 4|sao joao da barra
# Processing Record 44 of set 4|hofn
# Processing Record 45 of set 4|ormara
# Processing Record 46 of set 4|matara
# Processing Record 47 of set 4|rovaniemi
# Processing Record 48 of set 4|lorengau
# Processing Record 49 of set 4|henties bay
# Processing Record 50 of set 4|north las vegas
# Processing Record 1 of set 5|aklavik
# Processing Record 2 of set 5|uruzgan
# Processing Record 3 of set 5|port elizabeth
# Processing Record 4 of set 5|viedma
# Processing Record 5 of set 5|hwange
# Processing Record 6 of set 5|praia da vitoria
# Processing Record 7 of set 5|linqu
# Processing Record 8 of set 5|langham
# Processing Record 9 of set 5|ruidoso
# Processing Record 10 of set 5|dickinson
# Processing Record 11 of set 5|talnakh
# Processing Record 12 of set 5|vaitape
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of set 5|banihal
# Processing Record 14 of set 5|calbuco
# Processing Record 15 of set 5|southbridge
# Processing Record 16 of set 5|narsaq
# Processing Record 17 of set 5|victoria
# Processing Record 18 of set 5|meadow lake
# Processing Record 19 of set 5|saint george
# Processing Record 20 of set 5|skagen
# Processing Record 21 of set 5|korla
# Processing Record 22 of set 5|enshi
# Processing Record 23 of set 5|dunkwa
# Processing Record 24 of set 5|wuan
# Processing Record 25 of set 5|apatou
# Processing Record 26 of set 5|hualmay
# Processing Record 27 of set 5|cruzilia
# Processing Record 28 of set 5|mayor pablo lagerenza
# Processing Record 29 of set 5|barrow
# Processing Record 30 of set 5|san carlos de bariloche
# Processing Record 31 of set 5|charleston
# Processing Record 32 of set 5|port lincoln
# Processing Record 33 of set 5|vila velha
# Processing Record 34 of set 5|novoanninskiy
# Processing Record 35 of set 5|itarema
# City not found. Skipping...
# Processing Record 36 of set 5|simao
# Processing Record 37 of set 5|benjamin aceval
# Processing Record 38 of set 5|rosarito
# Processing Record 39 of set 5|uong bi
# Processing Record 40 of set 5|sumenep
# City not found. Skipping...
# Processing Record 41 of set 5|mondovi
# City not found. Skipping...
# Processing Record 42 of set 5|namibe
# Processing Record 43 of set 5|jabinyanah
# Processing Record 44 of set 5|wichian buri
# Processing Record 45 of set 5|izvoarele sucevei
# Processing Record 46 of set 5|irati
# Processing Record 47 of set 5|fairbanks
# Processing Record 48 of set 5|camacha
# Processing Record 49 of set 5|kiunga
# Processing Record 50 of set 5|marabba
# Processing Record 1 of set 6|coahuayana
# Processing Record 2 of set 6|namatanai
# Processing Record 3 of set 6|antsla
# Processing Record 4 of set 6|novokayakent
# Processing Record 5 of set 6|chokurdakh
# Processing Record 6 of set 6|port hedland
# Processing Record 7 of set 6|carutapera
# City not found. Skipping...
# Processing Record 8 of set 6|ayan
# Processing Record 9 of set 6|nelson bay
# Processing Record 10 of set 6|khandyga
# Processing Record 11 of set 6|coos bay
# Processing Record 12 of set 6|kensington
# Processing Record 13 of set 6|ketchikan
# Processing Record 14 of set 6|ende
# Processing Record 15 of set 6|atar
# Processing Record 16 of set 6|araguaina
# Processing Record 17 of set 6|strelka
# Processing Record 18 of set 6|khatanga
# Processing Record 19 of set 6|karpathos
# Processing Record 20 of set 6|ust-maya
# Processing Record 21 of set 6|ilulissat
# Processing Record 22 of set 6|sola
# Processing Record 23 of set 6|kaoma
# Processing Record 24 of set 6|tupaciguara
# Processing Record 25 of set 6|kjollefjord
# Processing Record 26 of set 6|mabaruma
# Processing Record 27 of set 6|chama
# Processing Record 28 of set 6|parana
# Processing Record 29 of set 6|chaiya
# Processing Record 30 of set 6|bela
# Processing Record 31 of set 6|san ramon
# Processing Record 32 of set 6|hit
# Processing Record 33 of set 6|waipawa
# Processing Record 34 of set 6|manzhouli
# Processing Record 35 of set 6|ruhengeri
# Processing Record 36 of set 6|gogrial
# Processing Record 37 of set 6|bossier city
# Processing Record 38 of set 6|seoul
# Processing Record 39 of set 6|san lorenzo
# Processing Record 40 of set 6|nybro
# Processing Record 41 of set 6|tromso
# Processing Record 42 of set 6|airai
# Processing Record 43 of set 6|chapadinha
# Processing Record 44 of set 6|isla mujeres
# Processing Record 45 of set 6|merauke
# City not found. Skipping...
# Processing Record 46 of set 6|manado
# Processing Record 47 of set 6|muros
# Processing Record 48 of set 6|morden
# Processing Record 49 of set 6|souillac
# Processing Record 50 of set 6|trincomalee
# Processing Record 1 of set 7|beloha
# Processing Record 2 of set 7|nicoya
# Processing Record 3 of set 7|karonga
# City not found. Skipping...
# Processing Record 4 of set 7|coihaique
# Processing Record 5 of set 7|dubti
# Processing Record 6 of set 7|ambilobe
# Processing Record 7 of set 7|sarny
# Processing Record 8 of set 7|saldanha
# City not found. Skipping...
# Processing Record 9 of set 7|milledgeville
# Processing Record 10 of set 7|tiarei
# Processing Record 11 of set 7|evinayong
# Processing Record 12 of set 7|mbaiki
# Processing Record 13 of set 7|nara
# Processing Record 14 of set 7|cayenne
# Processing Record 15 of set 7|melita
# Processing Record 16 of set 7|marzuq
# Processing Record 17 of set 7|heswall
# Processing Record 18 of set 7|bodden town
# Processing Record 19 of set 7|nurota
# Processing Record 20 of set 7|adrar
# Processing Record 21 of set 7|paita
# Processing Record 22 of set 7|castro
# Processing Record 23 of set 7|churapcha
# Processing Record 24 of set 7|orbetello
# Processing Record 25 of set 7|ornskoldsvik
# Processing Record 26 of set 7|salinas
# Processing Record 27 of set 7|hamilton
# Processing Record 28 of set 7|uglovskoye
# Processing Record 29 of set 7|asfi
# Processing Record 30 of set 7|quelimane
# City not found. Skipping...
# Processing Record 31 of set 7|tsiroanomandidy
# Processing Record 32 of set 7|mehriz
# Processing Record 33 of set 7|portland
# Processing Record 34 of set 7|messina
# Processing Record 35 of set 7|bubaque
# Processing Record 36 of set 7|takoradi
# Processing Record 37 of set 7|sept-iles
# Processing Record 38 of set 7|ponta delgada
# City not found. Skipping...
# Processing Record 39 of set 7|manacapuru
# Processing Record 40 of set 7|urdoma
# Processing Record 41 of set 7|onega
# Processing Record 42 of set 7|yerbogachen
# Processing Record 43 of set 7|baiyin
# City not found. Skipping...
# Processing Record 44 of set 7|isla vista
# Processing Record 45 of set 7|alpena
# Processing Record 46 of set 7|upernavik
# Processing Record 47 of set 7|mayenne
# Processing Record 48 of set 7|tam ky
# Processing Record 49 of set 7|sanok
# Processing Record 50 of set 7|deputatskiy
# Processing Record 1 of set 8|tucuru
# Processing Record 2 of set 8|erenhot
# Processing Record 3 of set 8|mugango
# Processing Record 4 of set 8|carbonia
# Processing Record 5 of set 8|dutlwe
# Processing Record 6 of set 8|arandis
# Processing Record 7 of set 8|naze
# Processing Record 8 of set 8|khasan
# Processing Record 9 of set 8|maniitsoq
# Processing Record 10 of set 8|abhar
# Processing Record 11 of set 8|george
# Processing Record 12 of set 8|tiksi
# Processing Record 13 of set 8|broken hill
# Processing Record 14 of set 8|fort saint james
# Processing Record 15 of set 8|udachnyy
# City not found. Skipping...
# Processing Record 16 of set 8|bonfim
# Processing Record 17 of set 8|pinega
# Processing Record 18 of set 8|bakel
# Processing Record 19 of set 8|port shepstone
# City not found. Skipping...
# Processing Record 20 of set 8|baykit
# City not found. Skipping...
# Processing Record 21 of set 8|moose factory
# Processing Record 22 of set 8|bethel
# Processing Record 23 of set 8|caravelas
# Processing Record 24 of set 8|puerto madryn
# Processing Record 25 of set 8|asmara
# Processing Record 26 of set 8|yamada
# Processing Record 27 of set 8|aginskoye
# Processing Record 28 of set 8|illapel
# Processing Record 29 of set 8|huarmey
# Processing Record 30 of set 8|rolla
# Processing Record 31 of set 8|maxixe
# Processing Record 32 of set 8|baruun-urt
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of set 8|iquitos
# Processing Record 34 of set 8|nantucket
# Processing Record 35 of set 8|dalbandin
# Processing Record 36 of set 8|smoky lake
# Processing Record 37 of set 8|severnyy
# Processing Record 38 of set 8|san pedro
# Processing Record 39 of set 8|kloulklubed
# Processing Record 40 of set 8|flinders
# Processing Record 41 of set 8|papara
# Processing Record 42 of set 8|rawson
# Processing Record 43 of set 8|tete
# Processing Record 44 of set 8|lakatoro
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of set 8|mianwali
# Processing Record 46 of set 8|benguela
# Processing Record 47 of set 8|kitzbuhel
# Processing Record 48 of set 8|los llanos de aridane
# Processing Record 49 of set 8|cabo san lucas
# Processing Record 50 of set 8|high level
# Processing Record 1 of set 9|ullapool
# Processing Record 2 of set 9|santa fe
# Processing Record 3 of set 9|zhigansk
# Processing Record 4 of set 9|kidal
# Processing Record 5 of set 9|mazagao
# City not found. Skipping...
# Processing Record 6 of set 9|lagunas
# Processing Record 7 of set 9|kota kinabalu
# Processing Record 8 of set 9|bakaly
# Processing Record 9 of set 9|hermon
# Processing Record 10 of set 9|yazman
# Processing Record 11 of set 9|carbonear
# Processing Record 12 of set 9|la ronge
# City not found. Skipping...
# Processing Record 13 of set 9|mount darwin
# Processing Record 14 of set 9|qaqortoq
# Processing Record 15 of set 9|douglas
# Processing Record 16 of set 9|lino lakes
# Processing Record 17 of set 9|port hardy
# City not found. Skipping...
# Processing Record 18 of set 9|koslan
# Processing Record 19 of set 9|zhovtneve
# Processing Record 20 of set 9|mezen
# Processing Record 21 of set 9|rabo de peixe
# Processing Record 22 of set 9|nova olimpia
# Processing Record 23 of set 9|mazatlan
# Processing Record 24 of set 9|lyngseidet
# Processing Record 25 of set 9|rafai
# Processing Record 26 of set 9|saint anthony
# Processing Record 27 of set 9|preetz
# Processing Record 28 of set 9|jurm
# Processing Record 29 of set 9|tateyama
# Processing Record 30 of set 9|tessalit
# City not found. Skipping...
# Processing Record 31 of set 9|kautokeino
# Processing Record 32 of set 9|puerto baquerizo moreno
# Processing Record 33 of set 9|synya
# Processing Record 34 of set 9|antofagasta
# Processing Record 35 of set 9|leh
# Processing Record 36 of set 9|rocha
# Processing Record 37 of set 9|lircay
# Processing Record 38 of set 9|tual
# Processing Record 39 of set 9|narrabri
# Processing Record 40 of set 9|amparafaravola
# Processing Record 41 of set 9|maldonado

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
main_df = pd.DataFrame({"City": city_df, "Lat": lat, "Lng": long, 
                      "Max Temp": Max_Temp, "Humidity": Humidity, 
                      "Cloudiness":Cloudiness, "Wind Speed": Wind_Speed,
                     "Country": Country, "Date": Date})
main_df.to_csv (r"output_data/cities.csv")

main_df.count()
# Out:
# City          554
# Lat           554
# Lng           554
# Max Temp      554
# Humidity      554
# Cloudiness    554
# Wind Speed    554
# Country       554
# Date          554
# dtype: int64

# %%
main_df.head(5)
# Out:
#            City    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Nālūt  30.33  10.85     81.00        24           0        6.40
# 1       Camacha  33.08 -16.33     68.00        88          20        8.05
# 2  Richards Bay -28.78  32.04     52.38        74           0        3.56
# 3    Bredasdorp -34.53  20.04     44.60        87           0        6.93
# 4  Punta Arenas -53.15 -70.92     30.20        86           0        4.70
#
#   Country        Date
# 0      LY  1594951957
# 1      PT  1594951957
# 2      ZA  1594951957
# 3      ZA  1594951957
# 4      CL  1594951957

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Inspect the data for Humidity levels greater than 100%
main_df["Humidity"].max()
# Out:
# 100

# %%
# Create a dataframe removing cities with a humidity level greater than 100% (there are none)
main_df = main_df[main_df["Humidity"]<= 100]

main_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  554.000000  554.000000  554.000000  554.000000  554.000000   554.00000
# mean    19.849242   14.973845   67.572256   71.796029   48.933213     7.57435
# std     33.661118   91.192940   13.595222   19.401066   40.269044     5.10333
# min    -54.800000 -175.200000   15.800000    1.000000    0.000000     0.22000
# 25%     -8.372500  -66.777500   57.200000   61.250000    2.000000     3.38000
# 50%     23.095000   23.625000   69.055000   75.000000   45.000000     6.41000
# 75%     48.770000   94.482500   79.000000   87.000000   90.000000    10.68000
# max     78.220000  178.420000   98.600000  100.000000  100.000000    29.97000
#
#                Date
# count  5.540000e+02
# mean   1.594952e+09
# std    5.933074e+01
# min    1.594952e+09
# 25%    1.594952e+09
# 50%    1.594952e+09
# 75%    1.594952e+09
# max    1.594952e+09

# %%
# Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  pimentel  -6.84  -79.93     66.20        29          75        5.82
# 1  victoria  22.29  114.16     69.01        88          40       18.34
# 2    padang  -0.95  100.35     79.90        75          99        1.63
# 3    hasaki  35.73  140.83     55.00       100          75        4.70
# 4   kahului  20.89 -156.47     70.00        88           1        7.63
#
#   Country        Date
# 0      PE  1585764415
# 1      HK  1585764288
# 2      ID  1585764115
# 3      JP  1585764415
# 4      US  1585764415

# %%
# Extract relevant fields from the data frame

# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# New (x, y) Variables
latitude = main_df["Lat"]
Max_T = main_df["Max Temp"]

# Scatter Plot
plt.scatter(latitude, Max_T, marker ="o", facecolors ="lightskyblue", edgecolors ="black")

# Formatting
plt.grid()
plt.title("City Latitude vs Max Temperature 04/01/2020")
plt.xlabel("City Latitude")
plt.ylabel("Max Temperature")
plt.savefig(r"output_data/Fig1.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# New (y) variable
Humidity_data = main_df["Humidity"]

# Scatter Plot
plt.scatter(latitude, Humidity_data, marker = "o", facecolors = "lightskyblue", edgecolors = "black")

# Formatting
plt.grid()
plt.title("City Latitude vs Humidity 04/15/2020")
plt.xlabel("City Latitude")
plt.ylabel("Humidity (%)")

# Save the graph to a PNG
plt.savefig(r"output_data/Fig2.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# New (y) variable
Cloud_data = main_df["Cloudiness"]

# Scatter Plot
plt.scatter(latitude, Cloud_data, marker = "o", facecolors = "lightskyblue", edgecolors = "black")

# Formatting
plt.grid()
plt.title("City Latitude vs Cloudiness 04/01/2020")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness (%)")

# Save the graph to a PNG
plt.savefig(r"output_data/Fig3.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# New (y) variable
Wind_data = main_df["Wind Speed"]

# Scatter Plot
plt.scatter(latitude, Wind_data, marker = "o", facecolors = "lightskyblue", edgecolors = "black")

# Formatting
plt.grid()
plt.title("City Latitude vs Wind Speed 04/15/2020")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig(r"output_data/Fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def plot_linear_regression(x,y,title,text_coordinates):
    (slope, intercept,rvalue, pvalue, stderr) = linregress(x,y)
    regress_values = x*slope + intercept
    line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
    plt.scatter(x, y, marker = "o", facecolors = "lightskyblue", edgecolors = "black")
    plt.plot(x, regress_values, color = 'red')
    plt.annotate(line_eq, text_coordinates, color = 'red', fontsize = 14)
    plt.xlabel("Latitude")
    plt.ylabel(title)
    plt.show()
    print(f"The r-squared is: {rvalue**2}")

# %%
# Create Northern and Southern Hemisphere DataFrames
Northern_df = main_df[main_df["Lat"]>0]
Southern_df = main_df[main_df["Lat"]<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
 plot_linear_regression(Northern_df["Lat"], Northern_df["Max Temp"], "Max Temp",(10,20))
# Out:
# The r-squared is: 0.5143504037815285

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plot_linear_regression(Southern_df["Lat"], Southern_df["Max Temp"], "Max Temp",(-55,85))
# Out:
# The r-squared is: 0.5897962453387642

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
 plot_linear_regression(Northern_df["Lat"], Northern_df["Humidity"], "Max Temp",(50,12))
# Out:
# The r-squared is: 7.522063071983698e-05

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plot_linear_regression(Southern_df["Lat"], Southern_df["Humidity"], "Max Temp",(-55,20))
# Out:
# The r-squared is: 0.006227312300564707

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plot_linear_regression(Northern_df["Lat"], Northern_df["Cloudiness"], "Max Temp",(50,33))
# Out:
# The r-squared is: 0.00016732613160618515

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plot_linear_regression(Southern_df["Lat"], Southern_df["Cloudiness"], "Max Temp",(-56,25))
# Out:
# The r-squared is: 0.003010585121013572

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plot_linear_regression(Northern_df["Lat"], Northern_df["Wind Speed"], "Max Temp",(5,30))
# Out:
# The r-squared is: 0.0012660224484120721

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plot_linear_regression(Southern_df["Lat"], Southern_df["Wind Speed"], "Max Temp",(-56,13))
# Out:
# The r-squared is: 0.00040401382031721996
